# %%
import sympy
from dual import Dual
from mathfunctions import *
from function import Function

# %%
sin.register(sympy.Basic, sympy.sin)
cos.register(sympy.Basic, sympy.cos)

# %%
x = Dual(sympy.Symbol('x'), 1)
